# %%
import re
import csv
import torch as th
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import numpy as np
#import nltk
from collections import Counter 
import matplotlib.pyplot as plt
from math import log
import time

# %% [markdown]
# # On génère les série temporelle

# %%
def generate_first_type_time_series(D):
    return np.array([[np.sin(np.divide(2*np.pi*i*t, 64)) for t in range(128)] for i in range(1,D+1)])

# %%
def generate_second_type_time_series(D):
    fst_type = generate_first_type_time_series(D)
    result = []
    frac = 1/(D-1)
    for i in range(1,D+1):
        loc = []
        for t in range(1,129):
            fst = fst_type[i-1,t-1]
            snd=frac*np.sum(np.delete(fst_type[:,t-1], i-1, axis=0))
            loc.append(fst+snd)
        result.append(loc)
    return np.array(result)

# %%
def generate_third_type_time_series(D):
    fst_type = generate_first_type_time_series(D)
    result = []
    frac = 1/(D-1)
    for i in range(1,D+1):
        loc = []
        for t in range(1,129):
            fst = fst_type[i-1,t-1]
            snd=frac*np.sum(np.delete(fst_type[:,t-1], i-1, axis=0))+ fst**2
            loc.append(fst+snd)
        result.append(loc)
    return np.array(result)

# %%
def generate_fourth_type_time_series(D):
    fst_type = generate_first_type_time_series(D)
    result = []
    frac = 1/(D-1)
    for i in range(1,D+1):
        loc = []            
        for t in range(1,129):
            if(i==D):
                loc.append(np.random.randn())
            else:
                fst = fst_type[i-1,t-1]
                snd=frac*np.sum(np.delete(fst_type[:,t-1], i-1, axis=0))
                loc.append(fst+snd)
        result.append(loc)
    return np.array(result)

# %%
def get_loader(D, MTS):
    data = []
    labels = []
    
    if MTS:
        series = generate_fourth_type_time_series(D)
    else : 
        series = generate_first_type_time_series(D)
    
    series = series.T
    for i in range(0,64):
        data.append(series[i:i+64, :])
        labels.append(series[i+64 , :])
    
    
    data = np.array(data)
    labels = np.array(labels) 
    train_data = TensorDataset(th.from_numpy(data).type(th.LongTensor), th.from_numpy(labels))
    train_loader = DataLoader(train_data, shuffle=False, batch_size=1)
    
    return train_loader

# %%
class GRU_forecaster(nn.Module):
    def __init__(self, nb_cells, hidden_size, input_size, rnn_dropout, window_size, conv_size):
        super(GRU_forecaster, self).__init__()
        
        self.nb_cells = nb_cells
        self.hidden_size = hidden_size
        self.input_size = input_size
        
        self.gru = nn.GRU(input_size, hidden_size, nb_cells, batch_first = True, dropout=rnn_dropout)

        
        
        
        ###Par rapport au papier, k=nbr de filtres et m=hidden size
        self.convList = nn.ModuleList([nn.Conv1d(1,1,window_size-1) for i in range(conv_size)])#32 fixed in the paper

        self.Wa = nn.Linear(hidden_size, conv_size)
        self.Wh = nn.Linear(hidden_size, hidden_size)
        self.Wv = nn.Linear(conv_size, hidden_size)
        self.Whp = nn.Linear(hidden_size, input_size)
        
        self.sigmoid = nn.Sigmoid()
            
    
    def forward(self, inputs, h0):
        inputs = inputs.view(1,-1,input_size).float()
        
        rnn_out, last_h = self.gru(inputs, h0)
        hidden = rnn_out.transpose(1,2)[:,:,:-1]
        
        hc = th.Tensor() #size m*k
        #l_out = self.getNbFeatures()
        
        for conv in self.convList:
            t = th.Tensor()
            for h in hidden[0]:
                h = h.view(1,1,-1)
                x = conv(h)
                t=th.cat([t,x],0)
            t = t.view(-1,1)
            hc=th.cat([hc,t],1)
        
        attention_weights = self.Wa(last_h).view(-1,1)
        attention_weights = (hc@attention_weights)
        attention_weights = self.sigmoid(attention_weights)
        
        vt = (attention_weights*hc).sum(dim=0) #ai * Hci
        
        hp = self.Wv(vt)+self.Wh(last_h)
        out = self.Whp(hp)
        return out, h
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        #hidden = th.Tensor(self.nb_cells, batch_size, self.hidden_size)
        hidden = weight.new(self.nb_cells, batch_size, self.hidden_size).zero_()
        return hidden

# %%
nb_cells=1
D= 6
learning_rate = 1e-3
hidden_size=10
input_size = D
gru=GRU_forecaster(nb_cells,hidden_size, input_size, 0.0,64,8)
loss_fn = nn.L1Loss()
loader = get_loader(D, False)

# %%
time_, final_acc, _ = train(gru, learning_rate,loader)
# Out:
# EPOCH 1
# Train Mean loss :  -0.17396607463682373
# ----------------------------------------
# EPOCH 2
# Train Mean loss :  -0.18720262353119405
# ----------------------------------------
# EPOCH 3
# Train Mean loss :  -0.19028640460762775
# ----------------------------------------
# EPOCH 4
# Train Mean loss :  -0.19278243256005656
# ----------------------------------------
# EPOCH 5
# Train Mean loss :  -0.19515356652756616
# ----------------------------------------
# EPOCH 6
# Train Mean loss :  -0.19865513541312763
# ----------------------------------------
# EPOCH 7
# Train Mean loss :  -0.20319334945427076
# ----------------------------------------
# EPOCH 8
# Train Mean loss :  -0.21277912973620292
# ----------------------------------------
# EPOCH 9
# Train Mean loss :  -0.23790774320291058
# ----------------------------------------
# EPOCH 10
# Train Mean loss :  -0.2685293562003772
# ----------------------------------------
# EPOCH 11
# Train Mean loss :  -0.2975135880708033
# ----------------------------------------
# EPOCH 12
# Train Mean loss :  -0.3404285001132029
# ----------------------------------------
# EPOCH 13
# Train Mean loss :  -0.4055167383300087
# ----------------------------------------
# EPOCH 14
# Train Mean loss :  -0.47816233622321946
# ----------------------------------------
# EPOCH 15
# Train Mean loss :  -0.5316885862113835
# ----------------------------------------
# EPOCH 16
# Train Mean loss :  -0.588913508501848
# ----------------------------------------
# EPOCH 17
# Train Mean loss :  -0.6283270152529882
# ----------------------------------------
# EPOCH 18
# Train Mean loss :  -0.6823006363761263
# ----------------------------------------
# EPOCH 19
# Train Mean loss :  -0.7304217704918073
# ----------------------------------------
# EPOCH 20
# Train Mean loss :  -0.7413963964417379
# ----------------------------------------
# EPOCH 21
# Train Mean loss :  -0.7751982226800669
# ----------------------------------------
# EPOCH 22
# Train Mean loss :  -0.8074846257012009
# ----------------------------------------
# EPOCH 23
# Train Mean loss :  -0.8002126159768325
# ----------------------------------------
# EPOCH 24
# Train Mean loss :  -0.827055567842421
# ----------------------------------------
# EPOCH 25
# Train Mean loss :  -0.8801501025923899
# ----------------------------------------
# EPOCH 26
# Train Mean loss :  -0.9054508896019163
# ----------------------------------------
# EPOCH 27
# Train Mean loss :  -0.9150202572611053
# ----------------------------------------
# EPOCH 28
# Train Mean loss :  -0.9278958085236971
# ----------------------------------------
# EPOCH 29
# Train Mean loss :  -0.9363111943607535
# ----------------------------------------
# EPOCH 30
# Train Mean loss :  -0.9863622501376607
# ----------------------------------------
# EPOCH 31
# Train Mean loss :  -1.001839851058328
# ----------------------------------------
# EPOCH 32
# Train Mean loss :  -0.9106867925693066
# ----------------------------------------
# EPOCH 33
# Train Mean loss :  -1.0014859136214465
# ----------------------------------------
# EPOCH 34
# Train Mean loss :  -1.0306306867085817
# ----------------------------------------
# EPOCH 35
# Train Mean loss :  -0.9653839784486413
# ----------------------------------------
# EPOCH 36
# Train Mean loss :  -1.055415826278572
# ----------------------------------------
# EPOCH 37
# Train Mean loss :  -0.9905254129821406
# ----------------------------------------
# EPOCH 38
# Train Mean loss :  -1.0229673459562199
# ----------------------------------------
# EPOCH 39
# Train Mean loss :  -1.0329118259778443
# ----------------------------------------
# EPOCH 40
# Train Mean loss :  -1.0029492420329764
# ----------------------------------------
# EPOCH 41
# Train Mean loss :  -1.0401162780042101
# ----------------------------------------
# EPOCH 42
# Train Mean loss :  -0.9872326905976753
# ----------------------------------------
# EPOCH 43
# Train Mean loss :  -1.030736572512117
# ----------------------------------------
# EPOCH 44
# Train Mean loss :  -1.062145174831056
# ----------------------------------------
# EPOCH 45
# Train Mean loss :  -1.0607367457489036
# ----------------------------------------
# EPOCH 46
# Train Mean loss :  -1.0399202872300766
# ----------------------------------------
# EPOCH 47
# Train Mean loss :  -1.0627138967226795
# ----------------------------------------
# EPOCH 48
# Train Mean loss :  -1.042419173636925
# ----------------------------------------
# EPOCH 49
# Train Mean loss :  -1.1126178264213542
# ----------------------------------------
# EPOCH 50
# Train Mean loss :  -1.1264007003174916
# ----------------------------------------
# EPOCH 51
# Train Mean loss :  -1.078003721190569
# ----------------------------------------
# EPOCH 52
# Train Mean loss :  -1.0798812466701595
# ----------------------------------------
# EPOCH 53
# Train Mean loss :  -1.0690069864394856
# ----------------------------------------
# EPOCH 54
# Train Mean loss :  -1.0590632167192902
# ----------------------------------------
# EPOCH 55
# Train Mean loss :  -1.0205672114789892
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -1.0489856164125066
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -1.1530618695851067
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -1.117732972657763
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -1.1194393407037266
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -1.1318164867660514
# ----------------------------------------

# %%
def train(model,lr,loader, max_epochs=60):

    predictions = []
    start = time.time()
    optim = th.optim.Adam(params=model.parameters(), lr=lr, weight_decay=1e-4)
    model.train()
    for i in range(max_epochs):
        n = 0 
        h = model.init_hidden(1)
        train_mean_loss=0
        for x, labels in loader:
            
            optim.zero_grad()
            h = h.data
            
            n+=1
            preds, _ = model(x, h)  
            
            preds=preds.view(1,-1)
            if (i== max_epochs-1):
                predictions.append(preds)
            labels=labels.view(1,-1).float()
            loss = loss_fn(preds, labels)
            h = h.detach()
            train_mean_loss+=loss.item()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(),
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -0.6094742381986468
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -0.6078656255660744
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -0.6204858096253153
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -0.6181133602529496
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -0.6260716559651311
# ----------------------------------------
# EPOCH 1
# Train Mean loss :  -0.17295115538045255
# ----------------------------------------
# EPOCH 2
# Train Mean loss :  -0.18761977997751894
# ----------------------------------------
# EPOCH 3
# Train Mean loss :  -0.19269024561619771
# ----------------------------------------
# EPOCH 4
# Train Mean loss :  -0.19580150106951077
# ----------------------------------------
# EPOCH 5
# Train Mean loss :  -0.2001025817512091
# ----------------------------------------
# EPOCH 6
# Train Mean loss :  -0.21085222587875496
# ----------------------------------------
# EPOCH 7
# Train Mean loss :  -0.22928012640926246
# ----------------------------------------
# EPOCH 8
# Train Mean loss :  -0.2477569354660454
# ----------------------------------------
# EPOCH 9
# Train Mean loss :  -0.2548551544152108
# ----------------------------------------
# EPOCH 10
# Train Mean loss :  -0.26413695321455505
# ----------------------------------------
# EPOCH 11
# Train Mean loss :  -0.28702513256158707
# ----------------------------------------
# EPOCH 12
# Train Mean loss :  -0.29841937366331683
# ----------------------------------------
# EPOCH 13
# Train Mean loss :  -0.31136299254675476
# ----------------------------------------
# EPOCH 14
# Train Mean loss :  -0.32225539521817753
# ----------------------------------------
# EPOCH 15
# Train Mean loss :  -0.3389974507632337
# ----------------------------------------
# EPOCH 16
# Train Mean loss :  -0.35895795181112033
# ----------------------------------------
# EPOCH 17
# Train Mean loss :  -0.35462156569913056
# ----------------------------------------
# EPOCH 18
# Train Mean loss :  -0.36059833583529877
# ----------------------------------------
# EPOCH 19
# Train Mean loss :  -0.359419729766924
# ----------------------------------------
# EPOCH 20
# Train Mean loss :  -0.3751766885917665
# ----------------------------------------
# EPOCH 21
# Train Mean loss :  -0.3884513304501498
# ----------------------------------------
# EPOCH 22
# Train Mean loss :  -0.3917578325513234
# ----------------------------------------
# EPOCH 23
# Train Mean loss :  -0.40777137296769855
# ----------------------------------------
# EPOCH 24
# Train Mean loss :  -0.40261417295080915
# ----------------------------------------
# EPOCH 25
# Train Mean loss :  -0.40078142867854544
# ----------------------------------------
# EPOCH 26
# Train Mean loss :  -0.4202531593227852
# ----------------------------------------
# EPOCH 27
# Train Mean loss :  -0.40332897756030434
# ----------------------------------------
# EPOCH 28
# Train Mean loss :  -0.4048696469019746
# ----------------------------------------
# EPOCH 29
# Train Mean loss :  -0.4330486969272042
# ----------------------------------------
# EPOCH 30
# Train Mean loss :  -0.43399344018217884
# ----------------------------------------
# EPOCH 31
# Train Mean loss :  -0.43595209400136664
# ----------------------------------------
# EPOCH 32
# Train Mean loss :  -0.4430666701711873
# ----------------------------------------
# EPOCH 33
# Train Mean loss :  -0.4346642380990878
# ----------------------------------------
# EPOCH 34
# Train Mean loss :  -0.4356988825234668
# ----------------------------------------
# EPOCH 35
# Train Mean loss :  -0.45176446986388324
# ----------------------------------------
# EPOCH 36
# Train Mean loss :  -0.45813049753179175
# ----------------------------------------
# EPOCH 37
# Train Mean loss :  -0.4480421986631349
# ----------------------------------------
# EPOCH 38
# Train Mean loss :  -0.4568009257100897
# ----------------------------------------
# EPOCH 39
# Train Mean loss :  -0.4598417687204328
# ----------------------------------------
# EPOCH 40
# Train Mean loss :  -0.4670692186627078
# ----------------------------------------
# EPOCH 41
# Train Mean loss :  -0.46484963134176127
# ----------------------------------------
# EPOCH 42
# Train Mean loss :  -0.47586908349181745
# ----------------------------------------
# EPOCH 43
# Train Mean loss :  -0.4662447430441682
# ----------------------------------------
# EPOCH 44
# Train Mean loss :  -0.4778794635424936
# ----------------------------------------
# EPOCH 45
# Train Mean loss :  -0.47984810244306725
# ----------------------------------------
# EPOCH 46
# Train Mean loss :  -0.4794091588997603
# ----------------------------------------
# EPOCH 47
# Train Mean loss :  -0.4724718222804711
# ----------------------------------------
# EPOCH 48
# Train Mean loss :  -0.47753074045846516
# ----------------------------------------
# EPOCH 49
# Train Mean loss :  -0.4849356165800167
# ----------------------------------------
# EPOCH 50
# Train Mean loss :  -0.49423889782166497
# ----------------------------------------
# EPOCH 51
# Train Mean loss :  -0.4813170138604305
# ----------------------------------------
# EPOCH 52
# Train Mean loss :  -0.49674402252985206
# ----------------------------------------
# EPOCH 53
# Train Mean loss :  -0.5048559786326582
# ----------------------------------------
# EPOCH 54
# Train Mean loss :  -0.49720384910796006
# ----------------------------------------
# EPOCH 55
# Train Mean loss :  -0.4992200556044192
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -0.4916954979443451
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -0.49577892497884024
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -0.5165014563968843
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -0.5242389108345171
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -0.5243095090613299
# ----------------------------------------

# %%
plt.plot([i for i in range(1,6)], final_accs, 'r+')

# %%
plt.plot([i for i in range(1,6)], times, 'r+')

# %% [markdown]
# # PLOT DES RESULTATS DE NOTRE MODELE ET COMPARAISON AVEC LE VRAI TRUC EN DIM 6

# %%
nb_cells=1
learning_rate = 1e-3
hidden_size=12
input_size=6
gru=GRU_forecaster(nb_cells,hidden_size, input_size, 0.0,64,8)
loss_fn = nn.L1Loss()
D= 6
loader = get_loader(D, False)
_ , _ , predictions  = train(gru, learning_rate,loader, 60)
# Out:
# EPOCH 1
# Train Mean loss :  -0.159727907558105
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-966cafb99c8f> in <module>
#       7 D= 6
#       8 loader = get_loader(D, False)
# ----> 9 _ , _ , predictions  = train(gru, learning_rate,loader, 60)
#
# <ipython-input-23-0ab370340c30> in train(model, lr, loader, max_epochs)
#      15
#      16             n+=1
# ---> 17             preds, _ = model(x, h)
#      18
#      19             preds=preds.view(1,-1)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-22-b3cd302f31e4> in forward(self, inputs, h0)
#      26         inputs = inputs.view(1,-1,input_size).float()
#      27
# ---> 28         rnn_out, last_h = self.gru(inputs, h0)
#      29         hidden = rnn_out.transpose(1,2)[:,:,:-1]
#      30
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     209         if batch_sizes is None:
#     210             result = _impl(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 211                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     212         else:
#     213             result = _impl(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %%
prediction_list = []
for i in range(D):
    l = []
    for j in range(64):
        l.append(predictions[j][0][i])
    prediction_list.append(l)

# %%
true_list = generate_first_type_time_series(6)

# %%
for i in range(D):
    plt.plot(prediction_list[i])
    plt.plot(true_list[i][64:])
    plt.show()

# %% [markdown]
# ## SECOND TOY EXAMPLES PLOTS

# %%
nb_cells=1
learning_rate = 1e-3
hidden_size=12
input_size=6
gru=GRU_forecaster(nb_cells,hidden_size, input_size, 0.0,64,8)
loss_fn = nn.L1Loss()
D= 6
loader = get_loader(D, True)
_ , _ , predictions  = train(gru, learning_rate,loader, 60)
# Out:
# EPOCH 1
# Train Mean loss :  -0.15726713274134904
# ----------------------------------------
# EPOCH 2
# Train Mean loss :  -0.16124897153322668
# ----------------------------------------
# EPOCH 3
# Train Mean loss :  -0.21125050853533092
# ----------------------------------------
# EPOCH 4
# Train Mean loss :  -0.2760366678240294
# ----------------------------------------
# EPOCH 5
# Train Mean loss :  -0.3984562807516678
# ----------------------------------------
# EPOCH 6
# Train Mean loss :  -0.5193876692378129
# ----------------------------------------
# EPOCH 7
# Train Mean loss :  -0.5392701372239891
# ----------------------------------------
# EPOCH 8
# Train Mean loss :  -0.6235701795753246
# ----------------------------------------
# EPOCH 9
# Train Mean loss :  -0.655193976020206
# ----------------------------------------
# EPOCH 10
# Train Mean loss :  -0.6261300372233601
# ----------------------------------------
# EPOCH 11
# Train Mean loss :  -0.6800273953329246
# ----------------------------------------
# EPOCH 12
# Train Mean loss :  -0.739986067320741
# ----------------------------------------
# EPOCH 13
# Train Mean loss :  -0.7404697924956162
# ----------------------------------------
# EPOCH 14
# Train Mean loss :  -0.7474123065174494
# ----------------------------------------
# EPOCH 15
# Train Mean loss :  -0.7503782608603465
# ----------------------------------------
# EPOCH 16
# Train Mean loss :  -0.8176714776491365
# ----------------------------------------
# EPOCH 17
# Train Mean loss :  -0.8987646837739289
# ----------------------------------------
# EPOCH 18
# Train Mean loss :  -0.8414061198820844
# ----------------------------------------
# EPOCH 19
# Train Mean loss :  -0.9341902331851453
# ----------------------------------------
# EPOCH 20
# Train Mean loss :  -0.8885283657532582
# ----------------------------------------
# EPOCH 21
# Train Mean loss :  -0.8760686347805542
# ----------------------------------------
# EPOCH 22
# Train Mean loss :  -0.8789254410000957
# ----------------------------------------
# EPOCH 23
# Train Mean loss :  -0.902513659617565
# ----------------------------------------
# EPOCH 24
# Train Mean loss :  -0.8435050348206492
# ----------------------------------------
# EPOCH 25
# Train Mean loss :  -0.8708774108975396
# ----------------------------------------
# EPOCH 26
# Train Mean loss :  -1.0336398316000373
# ----------------------------------------
# EPOCH 27
# Train Mean loss :  -0.9836010580866981
# ----------------------------------------
# EPOCH 28
# Train Mean loss :  -0.9215898093427418
# ----------------------------------------
# EPOCH 29
# Train Mean loss :  -0.8884362343264574
# ----------------------------------------
# EPOCH 30
# Train Mean loss :  -1.021983536048505
# ----------------------------------------
# EPOCH 31
# Train Mean loss :  -0.9851783975451284
# ----------------------------------------
# EPOCH 32
# Train Mean loss :  -0.9624326843733441
# ----------------------------------------
# EPOCH 33
# Train Mean loss :  -0.971302747701017
# ----------------------------------------
# EPOCH 34
# Train Mean loss :  -0.9731890076050942
# ----------------------------------------
# EPOCH 35
# Train Mean loss :  -0.9094890651086552
# ----------------------------------------
# EPOCH 36
# Train Mean loss :  -1.0453748318305167
# ----------------------------------------
# EPOCH 37
# Train Mean loss :  -0.9291184703707904
# ----------------------------------------
# EPOCH 38
# Train Mean loss :  -0.9668547825588845
# ----------------------------------------
# EPOCH 39
# Train Mean loss :  -1.0274791109130381
# ----------------------------------------
# EPOCH 40
# Train Mean loss :  -1.0051337968125198
# ----------------------------------------
# EPOCH 41
# Train Mean loss :  -0.9153379489064323
# ----------------------------------------
# EPOCH 42
# Train Mean loss :  -1.071292033505029
# ----------------------------------------
# EPOCH 43
# Train Mean loss :  -0.9864628768667241
# ----------------------------------------
# EPOCH 44
# Train Mean loss :  -0.9507090911587361
# ----------------------------------------
# EPOCH 45
# Train Mean loss :  -0.9653866198421236
# ----------------------------------------
# EPOCH 46
# Train Mean loss :  -0.9660766272359697
# ----------------------------------------
# EPOCH 47
# Train Mean loss :  -0.8865192996308037
# ----------------------------------------
# EPOCH 48
# Train Mean loss :  -0.87783223434186
# ----------------------------------------
# EPOCH 49
# Train Mean loss :  -1.0156133701536942
# ----------------------------------------
# EPOCH 50
# Train Mean loss :  -0.9006916835642136
# ----------------------------------------
# EPOCH 51
# Train Mean loss :  -1.0091684786079456
# ----------------------------------------
# EPOCH 52
# Train Mean loss :  -1.0195913926582412
# ----------------------------------------
# EPOCH 53
# Train Mean loss :  -1.0490343110170137
# ----------------------------------------
# EPOCH 54
# Train Mean loss :  -1.0254077926381413
# ----------------------------------------
# EPOCH 55
# Train Mean loss :  -0.869733977701234
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -0.9128646174860604
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -1.0376214247250135
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -0.9882760362933809
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -0.9999265321291488
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -0.9874171464155068
# ----------------------------------------

# %%
prediction_list = []
for i in range(D):
    l = []
    for j in range(64):
        l.append(predictions[j][0][i])
    prediction_list.append(l)

# %%
true_list = generate_second_type_time_series(6)

# %%
for i in range(D):
    plt.plot(prediction_list[i])
    plt.plot(true_list[i][64:])
    plt.show()

# %% [markdown]
# ####  THIRD MODEL

# %%
nb_cells=1
learning_rate = 1e-3
hidden_size=12
input_size=6
gru=GRU_forecaster(nb_cells,hidden_size, input_size, 0.0,64,8)
loss_fn = nn.L1Loss()
D= 6
loader = get_loader(D, True)
_ , _ , predictions  = train(gru, learning_rate,loader, 60)
# Out:
# EPOCH 1
# Train Mean loss :  -0.1267766233247022
# ----------------------------------------
# EPOCH 2
# Train Mean loss :  -0.1655869058021605
# ----------------------------------------
# EPOCH 3
# Train Mean loss :  -0.2021890832866965
# ----------------------------------------
# EPOCH 4
# Train Mean loss :  -0.24672358238594547
# ----------------------------------------
# EPOCH 5
# Train Mean loss :  -0.28359452976910515
# ----------------------------------------
# EPOCH 6
# Train Mean loss :  -0.3171757165551016
# ----------------------------------------
# EPOCH 7
# Train Mean loss :  -0.31635021414335934
# ----------------------------------------
# EPOCH 8
# Train Mean loss :  -0.3813450545256334
# ----------------------------------------
# EPOCH 9
# Train Mean loss :  -0.3872667313595497
# ----------------------------------------
# EPOCH 10
# Train Mean loss :  -0.4310635279362477
# ----------------------------------------
# EPOCH 11
# Train Mean loss :  -0.45964776651429023
# ----------------------------------------
# EPOCH 12
# Train Mean loss :  -0.5069369352595946
# ----------------------------------------
# EPOCH 13
# Train Mean loss :  -0.547263945031447
# ----------------------------------------
# EPOCH 14
# Train Mean loss :  -0.48664300063998744
# ----------------------------------------
# EPOCH 15
# Train Mean loss :  -0.5746725311745514
# ----------------------------------------
# EPOCH 16
# Train Mean loss :  -0.5223932391951724
# ----------------------------------------
# EPOCH 17
# Train Mean loss :  -0.5907146734536339
# ----------------------------------------
# EPOCH 18
# Train Mean loss :  -0.6277099937623557
# ----------------------------------------
# EPOCH 19
# Train Mean loss :  -0.6470107032535417
# ----------------------------------------
# EPOCH 20
# Train Mean loss :  -0.7161230119621466
# ----------------------------------------
# EPOCH 21
# Train Mean loss :  -0.7353398054471151
# ----------------------------------------
# EPOCH 22
# Train Mean loss :  -0.7494679929979122
# ----------------------------------------
# EPOCH 23
# Train Mean loss :  -0.5968057658998853
# ----------------------------------------
# EPOCH 24
# Train Mean loss :  -0.8145906790450801
# ----------------------------------------
# EPOCH 25
# Train Mean loss :  -0.8362574057838513
# ----------------------------------------
# EPOCH 26
# Train Mean loss :  -0.8045810580434629
# ----------------------------------------
# EPOCH 27
# Train Mean loss :  -0.7535723287561784
# ----------------------------------------
# EPOCH 28
# Train Mean loss :  -0.9861201242742195
# ----------------------------------------
# EPOCH 29
# Train Mean loss :  -0.8505670017630977
# ----------------------------------------
# EPOCH 30
# Train Mean loss :  -0.9015625144534267
# ----------------------------------------
# EPOCH 31
# Train Mean loss :  -0.833893512088001
# ----------------------------------------
# EPOCH 32
# Train Mean loss :  -0.9958662903663856
# ----------------------------------------
# EPOCH 33
# Train Mean loss :  -0.9415266569812047
# ----------------------------------------
# EPOCH 34
# Train Mean loss :  -0.933535325554734
# ----------------------------------------
# EPOCH 35
# Train Mean loss :  -0.8162918647686402
# ----------------------------------------
# EPOCH 36
# Train Mean loss :  -0.8827815713513115
# ----------------------------------------
# EPOCH 37
# Train Mean loss :  -0.8450915469316636
# ----------------------------------------
# EPOCH 38
# Train Mean loss :  -0.932152417856425
# ----------------------------------------
# EPOCH 39
# Train Mean loss :  -0.7412166169626666
# ----------------------------------------
# EPOCH 40
# Train Mean loss :  -0.9116294841187886
# ----------------------------------------
# EPOCH 41
# Train Mean loss :  -0.9419600458374155
# ----------------------------------------
# EPOCH 42
# Train Mean loss :  -1.0205732475582563
# ----------------------------------------
# EPOCH 43
# Train Mean loss :  -0.9384975303105223
# ----------------------------------------
# EPOCH 44
# Train Mean loss :  -0.944781886897692
# ----------------------------------------
# EPOCH 45
# Train Mean loss :  -0.9497546170388775
# ----------------------------------------
# EPOCH 46
# Train Mean loss :  -0.8293123219078823
# ----------------------------------------
# EPOCH 47
# Train Mean loss :  -0.9369813295156069
# ----------------------------------------
# EPOCH 48
# Train Mean loss :  -0.9070123042027454
# ----------------------------------------
# EPOCH 49
# Train Mean loss :  -0.9109409574285071
# ----------------------------------------
# EPOCH 50
# Train Mean loss :  -0.8471827205662118
# ----------------------------------------
# EPOCH 51
# Train Mean loss :  -0.9031582583076547
# ----------------------------------------
# EPOCH 52
# Train Mean loss :  -0.9349983679265952
# ----------------------------------------
# EPOCH 53
# Train Mean loss :  -0.9720292171727716
# ----------------------------------------
# EPOCH 54
# Train Mean loss :  -0.9417464335208157
# ----------------------------------------
# EPOCH 55
# Train Mean loss :  -0.9860811279560527
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -0.8371470912715079
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -1.0197110568459191
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -0.9002917612289507
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -0.9816821673961416
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -1.0195304355209234
# ----------------------------------------

# %%
prediction_list = []
for i in range(D):
    l = []
    for j in range(64):
        l.append(predictions[j][0][i])
    prediction_list.append(l)
    
true_list = generate_third_type_time_series(6)

for i in range(D):
    plt.plot(prediction_list[i])
    plt.plot(true_list[i][64:])
    plt.show()

# %% [markdown]
# # WITH NOISE

# %%
nb_cells=1
learning_rate = 1e-3
hidden_size=12
input_size=6
gru=GRU_forecaster(nb_cells,hidden_size, input_size, 0.0,64,8)
loss_fn = nn.L1Loss()
D= 6
loader = get_loader(D, True)
_ , _ , predictions  = train(gru, learning_rate,loader, 60)
# Out:
# EPOCH 1
# Train Mean loss :  -0.14803770848795048
# ----------------------------------------
# EPOCH 2
# Train Mean loss :  -0.17595788656397757
# ----------------------------------------
# EPOCH 3
# Train Mean loss :  -0.22207199317410922
# ----------------------------------------
# EPOCH 4
# Train Mean loss :  -0.2510421998636956
# ----------------------------------------
# EPOCH 5
# Train Mean loss :  -0.32447875613195265
# ----------------------------------------
# EPOCH 6
# Train Mean loss :  -0.35617260708641
# ----------------------------------------
# EPOCH 7
# Train Mean loss :  -0.4154085079172369
# ----------------------------------------
# EPOCH 8
# Train Mean loss :  -0.46365997017894717
# ----------------------------------------
# EPOCH 9
# Train Mean loss :  -0.5010627260582652
# ----------------------------------------
# EPOCH 10
# Train Mean loss :  -0.5305912502439238
# ----------------------------------------
# EPOCH 11
# Train Mean loss :  -0.5981422524262342
# ----------------------------------------
# EPOCH 12
# Train Mean loss :  -0.5736931698094102
# ----------------------------------------
# EPOCH 13
# Train Mean loss :  -0.5611997702441645
# ----------------------------------------
# EPOCH 14
# Train Mean loss :  -0.4846182997480852
# ----------------------------------------
# EPOCH 15
# Train Mean loss :  -0.55674041050334
# ----------------------------------------
# EPOCH 16
# Train Mean loss :  -0.5903139830523141
# ----------------------------------------
# EPOCH 17
# Train Mean loss :  -0.5863185184057154
# ----------------------------------------
# EPOCH 18
# Train Mean loss :  -0.6171804384450842
# ----------------------------------------
# EPOCH 19
# Train Mean loss :  -0.5826796458207325
# ----------------------------------------
# EPOCH 20
# Train Mean loss :  -0.6662117481528155
# ----------------------------------------
# EPOCH 21
# Train Mean loss :  -0.6518180382158286
# ----------------------------------------
# EPOCH 22
# Train Mean loss :  -0.5685159662282908
# ----------------------------------------
# EPOCH 23
# Train Mean loss :  -0.6621998196937251
# ----------------------------------------
# EPOCH 24
# Train Mean loss :  -0.6806134831688238
# ----------------------------------------
# EPOCH 25
# Train Mean loss :  -0.584130894610329
# ----------------------------------------
# EPOCH 26
# Train Mean loss :  -0.7274234681435622
# ----------------------------------------
# EPOCH 27
# Train Mean loss :  -0.6719274151882161
# ----------------------------------------
# EPOCH 28
# Train Mean loss :  -0.6565108920408046
# ----------------------------------------
# EPOCH 29
# Train Mean loss :  -0.6843017560356917
# ----------------------------------------
# EPOCH 30
# Train Mean loss :  -0.6708652402418992
# ----------------------------------------
# EPOCH 31
# Train Mean loss :  -0.6772212034704788
# ----------------------------------------
# EPOCH 32
# Train Mean loss :  -0.7061608620474299
# ----------------------------------------
# EPOCH 33
# Train Mean loss :  -0.6489322463583207
# ----------------------------------------
# EPOCH 34
# Train Mean loss :  -0.7243357172394825
# ----------------------------------------
# EPOCH 35
# Train Mean loss :  -0.6675644678518367
# ----------------------------------------
# EPOCH 36
# Train Mean loss :  -0.6514335079253447
# ----------------------------------------
# EPOCH 37
# Train Mean loss :  -0.713199902878811
# ----------------------------------------
# EPOCH 38
# Train Mean loss :  -0.7032875204793649
# ----------------------------------------
# EPOCH 39
# Train Mean loss :  -0.7557130890005578
# ----------------------------------------
# EPOCH 40
# Train Mean loss :  -0.6894676397379649
# ----------------------------------------
# EPOCH 41
# Train Mean loss :  -0.6624750156757677
# ----------------------------------------
# EPOCH 42
# Train Mean loss :  -0.7003087231200112
# ----------------------------------------
# EPOCH 43
# Train Mean loss :  -0.7421584979086892
# ----------------------------------------
# EPOCH 44
# Train Mean loss :  -0.6973544281292471
# ----------------------------------------
# EPOCH 45
# Train Mean loss :  -0.7116040927041225
# ----------------------------------------
# EPOCH 46
# Train Mean loss :  -0.6024294540429881
# ----------------------------------------
# EPOCH 47
# Train Mean loss :  -0.6969563178828377
# ----------------------------------------
# EPOCH 48
# Train Mean loss :  -0.7085618534933671
# ----------------------------------------
# EPOCH 49
# Train Mean loss :  -0.6792802652223299
# ----------------------------------------
# EPOCH 50
# Train Mean loss :  -0.6998188072546934
# ----------------------------------------
# EPOCH 51
# Train Mean loss :  -0.6737927314357051
# ----------------------------------------
# EPOCH 52
# Train Mean loss :  -0.6460130252002196
# ----------------------------------------
# EPOCH 53
# Train Mean loss :  -0.7328418943342636
# ----------------------------------------
# EPOCH 54
# Train Mean loss :  -0.7013086755406343
# ----------------------------------------
# EPOCH 55
# Train Mean loss :  -0.6735956162040236
# ----------------------------------------
# EPOCH 56
# Train Mean loss :  -0.6844914912434787
# ----------------------------------------
# EPOCH 57
# Train Mean loss :  -0.7072460111921236
# ----------------------------------------
# EPOCH 58
# Train Mean loss :  -0.6366023302408731
# ----------------------------------------
# EPOCH 59
# Train Mean loss :  -0.7358828291400571
# ----------------------------------------
# EPOCH 60
# Train Mean loss :  -0.7434258468602847
# ----------------------------------------

# %%
prediction_list = []
for i in range(D):
    l = []
    for j in range(64):
        l.append(predictions[j][0][i])
    prediction_list.append(l)
    
true_list = generate_fourth_type_time_series(6)

for i in range(D):
    plt.plot(prediction_list[i])
    plt.plot(true_list[i][64:])
    plt.show()
